-- %% [markdown]
-- ## Creating a managed table

-- %%
CREATE TABLE `dev_catalog`.`default`.Person_Table
(
  Person_ID  INT,
  FirstName  STRING,
  LastName  STRING
);

-- %%
INSERT INTO `dev_catalog`.`default`.Person_Table
VALUES
  (10, 'Steve', 'Rogers'),
  (20, 'Tony', 'Stark'),
  (30, 'Shanmukh', 'Sattiraju');

-- %%
describe extended `dev_catalog`.`default`.Person_Table

-- %%
DROP TABLE `dev_catalog`.`default`.Person_Table

-- %% [markdown]
-- ## External tables

-- %%
SHOW EXTERNAL LOCATIONS;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
DESCRIBE EXTERNAL LOCATION ext_location
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>url</th><th>credential_name</th><th>owner</th><th>created_by</th><th>created_at</th><th>comment</th></tr></thead><tbody><tr><td>ext_location</td><td>abfss://context@extstoragesep16.dfs.core.windows.net/dirext</td><td>cred_sep16</td><td>devopssachin@akankshasaxena390gmail.onmicrosoft.com</td><td>devopssachin@akankshasaxena390gmail.onmicrosoft.com</td><td>2025-09-16T06:42:09.735Z</td><td>abfss://context@extstoragesep16.dfs.core.windows.net/dirext</td></tr></tbody></table></div>

-- %%
CREATE TABLE devopscatalog.delta.Person_External
(
    Education_Level STRING,
    Line_Number INT,
    Employed INT,
    Unemployed INT,
    Industry STRING,
    Gender STRING,
    Date_Inserted STRING,
    dense_rank INT)
USING CSV
OPTIONS(
  'header' 'true'
)
LOCATION 'abfss://context@extstoragesep16.dfs.core.windows.net/dirext'
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
SELECT * FROM devopscatalog.delta.Person_External
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Education_Level</th><th>Line_Number</th><th>Employed</th><th>Unemployed</th><th>Industry</th><th>Gender</th><th>Date_Inserted</th><th>dense_rank</th></tr></thead><tbody></tbody></table></div>

-- %%
DESCRIBE EXTENDED devopscatalog.delta.Person_External
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
INSERT INTO devopscatalog.delta.Person_External
VALUES
('Bachelor', 1, 120, 30, 'IT', 'Male', '2025-09-16', 1),
('Masters', 2, 80, 20, 'Finance', 'Female', '2025-09-16', 2);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
drop table devopscatalog.delta.Person_External

-- %%
drop table devops_pankaj.star_schema.optimizestartable
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
