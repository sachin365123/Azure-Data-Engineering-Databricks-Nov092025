# %% [markdown]
# ## Deploy and Run AI Foundry Models in Azure Databricks

# %% [markdown]
# #### Install the Azure-AI-Inference SDK

# %%
# %pip install azure-ai-inference
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/124.9 kB ? eta -:--:--
#    ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/124.9 kB 1.8 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━ 92.2/124.9 kB 1.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 1.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# !pip install azure-ai-inference
# Out:
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %restart_python

# %% [markdown]
# Use the just below code in case, using in Jupyter Notebook or Colab for independent run

# %% [markdown]
# #### Populate the Environment Variables

# %% [markdown]
# #### Create a Basic Chat App

# %% [markdown]
# ### 3. Run a basic code sample: code taken from Modle + End Points, Azure AI Foundary

# %%
import os
from openai import AzureOpenAI

endpoint = "https://aug0520257389034242.openai.azure.com/"
model_name = "gpt-35-turbo"
deployment = "gpt-35-turbo-sadre"

subscription_key = "9dL86geb31JVVbeRKSa7HuIFzbD5oehPHGY92ggzaBvabGmorv56JQQJ99BHACHYHv6XJ3w3AAAAACOG9Qot"
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        }
    ],
    max_tokens=4096,
    temperature=1.0,
    top_p=1.0,
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# That's exciting! Paris is a beautiful and vibrant city with so much to see and do. Here are some must-see attractions and places to visit in Paris:
#
# 1. Eiffel Tower - A symbol of Paris, the Eiffel Tower offers stunning views of the city from its different levels.
#
# 2. Louvre Museum - Home to thousands of works of art, including the famous Mona Lisa.
#
# 3. Notre-Dame Cathedral - The iconic cathedral known for its stunning architecture and history.
#
# 4. Montmartre and Sacré-Cœur Basilica - Explore the charming Montmartre neighborhood and visit the beautiful Sacré-Cœur Basilica.
#
# 5. Champs-Élysées and Arc de Triomphe - Stroll down the famous avenue lined with shops and cafes, ending at the iconic Arc de Triomphe.
#
# 6. Seine River Cruise - Enjoy a relaxing boat cruise along the Seine River and admire the city's landmarks from the water.
#
# 7. Sainte-Chapelle - A breathtaking Gothic chapel known for its stunning stained glass windows.
#
# ...

# %% [markdown]
# #### 4. Explore more samples: code taken from Modle + End Points, Azure AI Foundary
# ##### Run a multi-turn conversation
# ###### This sample demonstrates a multi-turn conversation with the chat completion API. When using the model for a chat application, you'll need to manage the history of that conversation and send the latest messages to the model.

# %%
import os
from openai import AzureOpenAI

endpoint = "https://aug0520257389034242.openai.azure.com/"
model_name = "gpt-35-turbo"
deployment = "gpt-35-turbo-sadre"

subscription_key = "9dL86geb31JVVbeRKSa7HuIFzbD5oehPHGY92ggzaBvabGmorv56JQQJ99BHACHYHv6XJ3w3AAAAACOG9Qot"
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        },
        {
            "role": "assistant",
            "content": "Paris, the capital of France, is known for its stunning architecture, art museums, historical landmarks, and romantic atmosphere. Here are some of the top attractions to see in Paris:\n \n 1. The Eiffel Tower: The iconic Eiffel Tower is one of the most recognizable landmarks in the world and offers breathtaking views of the city.\n 2. The Louvre Museum: The Louvre is one of the world's largest and most famous museums, housing an impressive collection of art and artifacts, including the Mona Lisa.\n 3. Notre-Dame Cathedral: This beautiful cathedral is one of the most famous landmarks in Paris and is known for its Gothic architecture and stunning stained glass windows.\n \n These are just a few of the many attractions that Paris has to offer. With so much to see and do, it's no wonder that Paris is one of the most popular tourist destinations in the world.",
        },
        {
            "role": "user",
            "content": "What is so great about #1?",
        }
    ],
    max_tokens=4096,
    temperature=1.0,
    top_p=1.0,
    model=deployment
)

print(response.choices[0].message.content)
# Out:
# The Eiffel Tower is one of the most iconic and recognizable landmarks in the world, symbolizing the city of Paris and France as a whole. Here are some reasons why the Eiffel Tower is considered such a great attraction:
#
#  1. Iconic symbol: The Eiffel Tower is an iconic symbol of Paris and is instantly recognizable worldwide. It represents elegance, romance, and French culture.
#  2. Breathtaking views: Visitors can take an elevator ride to the top of the tower for panoramic views of the city of Paris. The views from the Eiffel Tower offer a unique perspective of the city's layout and architecture.
#  3. Architectural marvel: When it was completed in 1889, the Eiffel Tower was considered an architectural marvel and a feat of engineering. Its iron lattice structure was groundbreaking at the time and remains a masterpiece of design today.
#
# ...

# %%
import os
from openai import AzureOpenAI

endpoint = "https://aug0520257389034242.openai.azure.com/"
model_name = "gpt-35-turbo"
deployment = "gpt-35-turbo-sadre"

subscription_key = subscription_key
api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

response = client.chat.completions.create(
    stream=True,
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant.",
        },
        {
            "role": "user",
            "content": "I am going to Paris, what should I see?",
        }
    ],
    max_tokens=4096,
    temperature=1.0,
    top_p=1.0,
    model=deployment,
)

for update in response:
    if update.choices:
        print(update.choices[0].delta.content or "", end="")

client.close()
# Out:
# That's exciting! Paris is full of beautiful and famous attractions. Here are some must-see places in Paris:
#
# 1. Eiffel Tower: This iconic landmark is a must-visit for any trip to Paris. You can admire the view from the top or have a picnic in the nearby Champ de Mars park.
#
# 2. Louvre Museum: Home to thousands of works of art, including the famous Mona Lisa. It's worth spending a few hours exploring the museum's vast collection.
#
# 3. Notre-Dame Cathedral: A stunning example of French Gothic architecture, this cathedral is a must-see for its grandeur and history.
#
# 4. Montmartre: This charming neighborhood is known for its artistic history, cozy cafes, and the stunning Sacré-Cœur Basilica.
#
# 5. Seine River Cruise: Take a relaxing boat ride along the Seine River to see the city from a different perspective and admire the beautiful bridges and landmarks.
#
# ...
