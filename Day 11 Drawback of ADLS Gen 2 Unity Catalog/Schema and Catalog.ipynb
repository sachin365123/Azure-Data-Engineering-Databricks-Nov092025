# %% [markdown]
# # Show current Metastore

# %%
# %sql
SELECT CURRENT_METASTORE();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_metastore()</th></tr></thead><tbody><tr><td>azure:southindia:b75171d2-33dc-47f3-8682-2891758dd75a</td></tr></tbody></table></div>

# %% [markdown]
# # First Check your current Catalog where You are mounted

# %%
# %sql
SELECT current_catalog();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_catalog()</th></tr></thead><tbody><tr><td>devopscatalog</td></tr></tbody></table></div>

# %%
# %sql
select current_schema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_schema()</th></tr></thead><tbody><tr><td>devopsschema</td></tr></tbody></table></div>

# %% [markdown]
# # Show all your Catalogs

# %%
# %sql
show catalogs
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog</th></tr></thead><tbody><tr><td>devopscatalog</td></tr><tr><td>hive_metastore</td></tr><tr><td>main</td></tr><tr><td>samples</td></tr><tr><td>system</td></tr></tbody></table></div>

# %%
# %sql
create catalog devopscatalog

# %%
# %sql
create schema devopsschema

# %% [markdown]
# # Use specific Catalog

# %%
# %sql
use catalog devopscatalog
-- or use Spark code: spark.sql("""USE CATALOG `dev-catalog`""")

# %% [markdown]
# # Show all Schemas or Databases in current Catalog

# %%
# %sql
show schemas
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>default</td></tr><tr><td>devopsschema</td></tr><tr><td>information_schema</td></tr><tr><td>silver</td></tr></tbody></table></div>

# %%
# %sql
create schema if not exists `silver`

# %% [markdown]
# # Use certain Schema or Database now

# %%
# %sql
use schema devopsschema

# %% [markdown]
# # Show all granted Permisions to your Schema or Database

# %%
# %sql
SHOW GRANTS ON SCHEMA sachindb;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Grant relevant Permission through code

# %%
# %sql
GRANT USAGE, CREATE ON CATALOG catalogdevops TO `devopssachin@akankshasaxena390gmail.onmicrosoft.com`;

# %%
# %sql
GRANT USAGE ON SCHEMA catalogdevops.sachindb TO `devopssachin@akankshasaxena390gmail.onmicrosoft.com`;
GRANT CREATE ON SCHEMA catalogdevops.sachindb TO `devopssachin@akankshasaxena390gmail.onmicrosoft.com`;

# %% [markdown]
# # OR, other Method

# %%
# %sql
GRANT CREATE, USAGE ON SCHEMA sachindb TO `devopssachin@akankshasaxena390gmail.onmicrosoft.com`;

# %%
# %sql
DESCRIBE SCHEMA EXTENDED schemadevops.`silver`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database_description_item</th><th>database_description_value</th></tr></thead><tbody><tr><td>Catalog Name</td><td>schemadevops</td></tr><tr><td>Namespace Name</td><td>silver</td></tr><tr><td>Comment</td><td></td></tr><tr><td>Location</td><td></td></tr><tr><td>Owner</td><td>devopssachin@akankshasaxena390gmail.onmicrosoft.com</td></tr><tr><td>Properties</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastoredevops)</td></tr></tbody></table></div>

# %%
# %sql
CREATE TABLE `silver`.orders_new (
    order_id        INT,
    customer_name   STRING,
    product_name    STRING,
    quantity        INT,
    order_date      DATE
);

# %%
# %sql
CREATE TABLE `catalogdevops`.default.Person_Table
(
  Person_ID  INT,
  FirstName  STRING,
  LastName  STRING
);
# Out:
# ---------------------------------------------------------------------------
# SparkConnectGrpcException                 Traceback (most recent call last)
# File <command-7096695685470220>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'CREATE TABLE `catalogdevops`.default.Person_Table\n(\n  Person_ID  INT,\n  FirstName  STRING,\n  LastName  STRING\n);\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %sql
CREATE TABLE `catalogdevops`.sachindb.orders (
    order_id        INT,
    customer_name   STRING,
    product_name    STRING,
    quantity        INT,
    order_date      DATE
);
# Out:
# ---------------------------------------------------------------------------
# SparkConnectGrpcException                 Traceback (most recent call last)
# File <command-7096695685470229>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'CREATE TABLE `catalogdevops`.sachindb.orders (\n    order_id        INT,\n    customer_name   STRING,\n    product_name    STRING,\n    quantity        INT,\n    order_date      DATE\n);\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...
