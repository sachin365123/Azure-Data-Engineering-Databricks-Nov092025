# %% [markdown]
# ## Optimize our Delta Tables

# %% [markdown]
# ### Create our Schema

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS star_schema

# %%
# %sql
CREATE TABLE IF NOT EXISTS hive_metastore.star_schema.OptimizeStarTable
(
    Education_Level VARCHAR(50),
    Line_Number INT,
    Employed INT,
    Unemployed INT,
    Industry VARCHAR(50),
    Gender VARCHAR(10),
    Date_Inserted DATE,
    dense_rank INT
)

# %% [markdown]
# ## show all catalogs

# %%
# %sql
show catalogs
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog</th></tr></thead><tbody><tr><td>devops_pankaj</td></tr><tr><td>devopscatalog</td></tr><tr><td>hive_metastore</td></tr><tr><td>main</td></tr><tr><td>samples</td></tr><tr><td>system</td></tr></tbody></table></div>

# %% [markdown]
# ## Move devops_pankaj catalog

# %%
# %sql
use catalog devops_pankaj

# %% [markdown]
# ## Show all schemas

# %%
# %sql
show schemas
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>default</td></tr><tr><td>information_schema</td></tr><tr><td>star_schema</td></tr></tbody></table></div>

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS star_schema

# %% [markdown]
# ## use certain schema

# %%
# %sql
use schema star_schema

# %% [markdown]
# ## Create table in start_schema

# %%
# %sql
CREATE TABLE IF NOT EXISTS OptimizeStarTable
(
    Education_Level VARCHAR(50),
    Line_Number INT,
    Employed INT,
    Unemployed INT,
    Industry VARCHAR(50),
    Gender VARCHAR(10),
    Date_Inserted DATE,
    dense_rank INT
)

# %% [markdown]
# ## Insert first row

# %%
# %sql
-- Line number 100
INSERT INTO OptimizeStarTable
VALUES
    ('Bachelor', 100,  4500, 500, 'Networking', 'Male', '2023-07-12', 1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ## Insert Second row

# %%
# %sql
-- Line Number row is having value 101

INSERT INTO OptimizeStarTable
VALUES
    ('Bachelor', 101, 5200, 700, 'Networking', 'Male', '2023-07-12', 2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ## Insert third Rows

# %%
# %sql
-- Line number row is having value 102

INSERT INTO OptimizeStarTable
VALUES
('Master', 102, 6500, 500, 'Networking', 'Female', '2023-07-12', 3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ## Deleting a record

# %%
# %sql
DELETE FROM OptimizeStarTable
WHERE Line_Number = 101
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from OptimizeStarTable
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Education_Level</th><th>Line_Number</th><th>Employed</th><th>Unemployed</th><th>Industry</th><th>Gender</th><th>Date_Inserted</th><th>dense_rank</th></tr></thead><tbody><tr><td>Bachelor</td><td>100</td><td>4500</td><td>500</td><td>Networking</td><td>Male</td><td>2023-07-12</td><td>1</td></tr><tr><td>Master</td><td>9999999</td><td>6500</td><td>500</td><td>Networking</td><td>Female</td><td>2023-07-12</td><td>3</td></tr><tr><td>Bachelor</td><td>100</td><td>4500</td><td>500</td><td>Networking</td><td>Male</td><td>2023-07-12</td><td>1</td></tr><tr><td>Master</td><td>102</td><td>6500</td><td>500</td><td>Networking</td><td>Female</td><td>2023-07-12</td><td>3</td></tr></tbody></table></div>

# %% [markdown]
# ## Update this table

# %%
# %sql
UPDATE OptimizeStarTable
SET Line_Number = 9999999
WHERE Line_Number = 102
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ## Optimize Command

# %%
# %sql
OPTIMIZE OptimizeStarTable;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>abfss://contdevops@stgdevstoragesep.dfs.core.windows.net/b75171d2-33dc-47f3-8682-2891758dd75a/tables/b1330937-824f-4032-b83c-a635f9066ae2</td><td>List(1, 2, List(2675, 2675, 2675.0, 1, 2675), List(2574, 2574, 2574.0, 2, 5148), 0, null, null, 0, 1, 2, 0, true, 0, 0, 1757994859460, 1757994864851, 4, 1, null, List(0, 0), null, 8, 8, 654, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# ## Check your History

# %%
# %sql
describe history OptimizeStarTable
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>11</td><td>2025-09-16T05:59:44Z</td><td>147661884682398</td><td>devopssachin@akankshasaxena390gmail.onmicrosoft.com</td><td>UPDATE</td><td>Map(predicate -> ["(Line_Number#3132 = 102)"])</td><td>null</td><td>List(3379567522496830)</td><td>0911-064545-gxomxpfn</td><td>10</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 2573, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 2015, numDeletionVectorsUpdated -> 0, scanTimeMs -> 791, numAddedFiles -> 1, numUpdatedRows -> 1, numAddedBytes -> 2574, rewriteTimeMs -> 1222)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr><tr><td>10</td><td>2025-09-16T05:59:26Z</td><td>147661884682398</td><td>devopssachin@akankshasaxena390gmail.onmicrosoft.com</td><td>DELETE</td><td>Map(predicate -> ["(Line_Number#2319 = 101)"])</td><td>null</td><td>List(3379567522496830)</td><td>0911-064545-gxomxpfn</td><td>9</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 2574, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 4089, numDeletionVectorsUpdated -> 0, numDeletedRows -> 1, scanTimeMs -> 3522, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 556)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr><tr><td>9</td><td>2025-09-16T05:59:15Z</td><td>147661884682398</td><td>devopssachin@akankshasaxena390gmail.onmicrosoft.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(3379567522496830)</td><td>0911-064545-gxomxpfn</td><td>8</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 2573)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr><tr><td>8</td><td>2025-09-16T05:59:10Z</td><td>147661884682398</td><td>devopssachin@akankshasaxena390gmail.onmicrosoft.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(3379567522496830)</td><td>0911-064545-gxomxpfn</td><td>7</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 2574)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr><tr><td>7</td><td>2025-09-16T05:59:03Z</td><td>147661884682398</td><td>devopssachin@akankshasaxena390gmail.onmicrosoft.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(3379567522496830)</td><td>0911-064545-gxomxpfn</td><td>6</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 2574)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr><tr><td>6</td><td>2025-09-16T03:54:23Z</td><td>147661884682398</td><td>devopssachin@akankshasaxena390gmail.onmicrosoft.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> false, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(3379567522496830)</td><td>0911-064545-gxomxpfn</td><td>5</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 2, numRemovedBytes -> 5148, p25FileSize -> 2675, numDeletionVectorsRemoved -> 0, minFileSize -> 2675, numAddedFiles -> 1, maxFileSize -> 2675, p75FileSize -> 2675, p50FileSize -> 2675, numAddedBytes -> 2675)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr><tr><td>5</td><td>2025-09-16T03:45:35Z</td><td>147661884682398</td><td>devopssachin@akankshasaxena ...

# %%
# %sql
select * from OptimizeStarTable version as of 4
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Education_Level</th><th>Line_Number</th><th>Employed</th><th>Unemployed</th><th>Industry</th><th>Gender</th><th>Date_Inserted</th><th>dense_rank</th></tr></thead><tbody><tr><td>Bachelor</td><td>100</td><td>4500</td><td>500</td><td>Networking</td><td>Male</td><td>2023-07-12</td><td>1</td></tr><tr><td>Master</td><td>102</td><td>6500</td><td>500</td><td>Networking</td><td>Female</td><td>2023-07-12</td><td>3</td></tr></tbody></table></div>

# %% [markdown]
# ## Using timestamp AS OF in SQL

# %%
# %sql
SELECT *
FROM OptimizeStarTable TIMESTAMP AS OF "2025-09-16T05:59:15.000+00:00"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Education_Level</th><th>Line_Number</th><th>Employed</th><th>Unemployed</th><th>Industry</th><th>Gender</th><th>Date_Inserted</th><th>dense_rank</th></tr></thead><tbody><tr><td>Bachelor</td><td>100</td><td>4500</td><td>500</td><td>Networking</td><td>Male</td><td>2023-07-12</td><td>1</td></tr><tr><td>Master</td><td>9999999</td><td>6500</td><td>500</td><td>Networking</td><td>Female</td><td>2023-07-12</td><td>3</td></tr><tr><td>Bachelor</td><td>100</td><td>4500</td><td>500</td><td>Networking</td><td>Male</td><td>2023-07-12</td><td>1</td></tr><tr><td>Bachelor</td><td>101</td><td>5200</td><td>700</td><td>Networking</td><td>Male</td><td>2023-07-12</td><td>2</td></tr><tr><td>Master</td><td>102</td><td>6500</td><td>500</td><td>Networking</td><td>Female</td><td>2023-07-12</td><td>3</td></tr></tbody></table></div>
